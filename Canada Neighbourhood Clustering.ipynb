# %% [markdown]
# # Step 1: Install Wikipedia library and functions for this environment

# %%
import sys
# !{sys.executable} -m pip install wikipedia
# !{sys.executable} -m pip install folium
# Out:
# Requirement not upgraded as not directly required: wikipedia in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages
# Requirement not upgraded as not directly required: requests<3.0.0,>=2.0.0 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from wikipedia)
# Requirement not upgraded as not directly required: beautifulsoup4 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from wikipedia)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/47/28/b3199bf87100e389c1dff88a44a38936d27e5e99eece870b5308186217c8/folium-0.8.2-py2.py3-none-any.whl (87kB)
#     100% |████████████████████████████████| 92kB 8.3MB/s eta 0:00:01
# Requirement not upgraded as not directly required: jinja2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: requests in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: numpy in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: six in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement not upgraded as not directly required: MarkupSafe>=0.23 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from jinja2->folium)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.8.2

# %% [markdown]
# # Step 2: Use inbuilt wikipedia functions to extract and clean the table in the desired datafame format

# %%
import pandas as pd
import wikipedia as wp
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn' used to ignore the warn message
 
#Get the html source
html = wp.page("List of postal codes of Canada: M").html().encode("UTF-8")
df = pd.read_html(html)[0]
df.to_csv('beautifulsoup_pandas.csv',header=0,index=False)
#Data cleanup - Renaming columns appropriately, marking Not assigned as NaN and dropping the irrelevant rows, using groupby and aggregate functions to get the data frame 
df1=df.rename(index=str,columns={0:"Postcode",1:"Borough",2:"Neighbourhood"})
df1['Borough'].replace("Borough",np.nan,inplace=True) 
df1['Borough'].replace("Not assigned",np.nan, inplace=True)
df2=df1.dropna()
df2.reset_index(drop=True, inplace=True)
df2['Neighbourhood'].replace("Not assigned",df2['Borough'],inplace=True)
df3=pd.DataFrame(df2.groupby('Postcode',as_index=False).agg(lambda x:','.join(set(x))))
df3
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                        Malvern,Rouge
# 1                 Port Union,Rouge Hill,Highland Creek
# 2                      Morningside,West Hill,Guildwood
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6            Kennedy Park,Ionview,East Birchmount Park
# 7                        Golden Mile,Clairlea,Oakridge
# 8        Cliffside,Cliffcrest,Scarborough Village West
# 9                           Cliffside West,Birch Cliff
# 10   Wexford Heights,Dorset Park,Scarborough Town C...
# 11                                    Wexford,Maryvale
# 12                                           Agincourt
# 13               Sullivan,Clarks Corners,Tam O'Shanter
# 14   L'Amoreaux East,Steeles East,Agincourt North,M...
# 15                        Steeles West,L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                          Fairview,Oriole,Henry Farm
# 19                                     Bayview Village
# 20                             York Mills,Silver Hills
# 21                              Willowdale,Newtonbrook
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                     Flemingdon Park,Don Mills South
# 28       Wilson Heights,Bathurst Manor,Downsview North
# 29                      Northwood Park,York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                         Dufferin,Dovercourt Village
# 77                             Trinity,Little Portugal
# 78          Exhibition Place,Parkdale Village,Brockton
# 79              Upwood Park,North Park,Maple Leaf Park
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn
# 81                        Runnymede,The Junction North
# 82                        The Junction South,High Park
# 83                               Roncesvalles,Parkdale
# 84                                   Runnymede,Swansea
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88          Mimico South,Humber Bay Shores,New Toronto
# 89                               Long Branch,Alderwood
# 90         Montgomery Road,Old Mill North,The Kingsway
# 91   Kingsway Park South East,Old Mill South,The Qu...
# 92   South of Bloor,Kingsway Park South West,Mimico...
# 93                                    Islington Avenue
# 94   West Deane Park,Islington,Cloverdale,Martin Gr...
# 95   Bloordale Gardens,Markland Wood,Eringate,Old B...
# 96                                       Humber Summit
# 97                                     Humberlea,Emery
# 98                                              Weston
# 99                                           Westmount
# 100  Martin Grove Gardens,St. Phillips,Kingsview Vi...
# 101  Silverstone,South Steeles,Albion Gardens,Humbe...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %% [markdown]
# # Step 3: Printing the dataframe shape

# %%
df3.shape
# Out:
# (103, 3)

# %% [markdown]
# # Step 4: Reading Geocoding Data

# %%
df4 = pd.read_csv("http://cocl.us/Geospatial_data")
df4.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# # Step 5: Adding geocoding data to the dataframe

# %%
keys= df3.Postcode.unique()
for keys in df4['Postal Code']:
     df3['Latitude'] = df4['Latitude']
     df3['Longitude']= df4['Longitude']
        
df3
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                        Malvern,Rouge  43.806686 -79.194353
# 1                 Port Union,Rouge Hill,Highland Creek  43.784535 -79.160497
# 2                      Morningside,West Hill,Guildwood  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6            Kennedy Park,Ionview,East Birchmount Park  43.727929 -79.262029
# 7                        Golden Mile,Clairlea,Oakridge  43.711112 -79.284577
# 8        Cliffside,Cliffcrest,Scarborough Village West  43.716316 -79.239476
# 9                           Cliffside West,Birch Cliff  43.692657 -79.264848
# 10   Wexford Heights,Dorset Park,Scarborough Town C...  43.757410 -79.273304
# 11                                    Wexford,Maryvale  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13               Sullivan,Clarks Corners,Tam O'Shanter  43.781638 -79.304302
# 14   L'Amoreaux East,Steeles East,Agincourt North,M...  43.815252 -79.284577
# 15                        Steeles West,L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                          Fairview,Oriole,Henry Farm  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                             York Mills,Silver Hills  43.757490 -79.374714
# 21                              Willowdale,Newtonbrook  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                     Flemingdon Park,Don Mills South  43.725900 -79.340923
# 28       Wilson Heights,Bathurst Manor,Downsview North  43.754328 -79.442259
# 29                      Northwood Park,York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                         Dufferin,Dovercourt Village  43.669005 -79.442259
# 77                             Trinity,Little Portugal  43.647927 -79.419750
# 78          Exhibition Place,Parkdale Village,Brockton  43.636847 -79.428191
# 79              Upwood Park,North Park,Maple Leaf Park  43.713756 -79.490074
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.691116 -79.476013
# 81                        Runnymede,The Junction North  43.673185 -79.487262
# 82                        The Junction South,High Park  43.661608 -79.464763
# 83                               Roncesvalles,Parkdale  43.648960 -79.456325
# 84                                   Runnymede,Swansea  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88          Mimico South,Humber Bay Shores,New Toronto  43.605647 -79.501321
# 89                               Long Branch,Alderwood  43.602414 -79.543484
# 90         Montgomery Road,Old Mill North,The Kingsway  43.653654 -79.506944
# 91   Kingsway Park South East,Old Mill South,The Qu...  43.636258 -79.498509
# 92   South of Bloor,Kingsway Park South West,Mimico...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   West Deane Park,Islington,Cloverdale,Martin Gr...  43.650943 -79.554724
# 95   Bloordale Gardens,Markland Wood,Eringate,Old B...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                     Humberlea,Emery  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Martin Grove Gardens,St. Phillips,Kingsview Vi...  43.688905 -79.554724
# 101  Silverstone,South Steeles,Albion Gardens,Humbe...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
from geopy.geocoders import Nominatim # importing the geocoder package
import folium

#Cleaning the data to replace east, west, central and downtown Toronto with Toronto
df3['Borough'].replace("East Toronto","Toronto",inplace=True)
df3['Borough'].replace("Central Toronto","Toronto",inplace=True)
df3['Borough'].replace("Downtown Toronto","Toronto",inplace=True)
df3['Borough'].replace("West Toronto","Toronto",inplace=True)
toronto_data = df3[df3['Borough'] == 'Toronto'].reset_index(drop=True)
toronto_data
# Out:
#    Postcode  Borough                                      Neighbourhood  \
# 0       M4E  Toronto                                        The Beaches
# 1       M4K  Toronto                        The Danforth West,Riverdale
# 2       M4L  Toronto                      The Beaches West,India Bazaar
# 3       M4M  Toronto                                    Studio District
# 4       M4N  Toronto                                      Lawrence Park
# 5       M4P  Toronto                                   Davisville North
# 6       M4R  Toronto                                 North Toronto West
# 7       M4S  Toronto                                         Davisville
# 8       M4T  Toronto                         Summerhill East,Moore Park
# 9       M4V  Toronto  Summerhill West,Forest Hill SE,Deer Park,Rathn...
# 10      M4W  Toronto                                           Rosedale
# 11      M4X  Toronto                         Cabbagetown,St. James Town
# 12      M4Y  Toronto                               Church and Wellesley
# 13      M5A  Toronto                           Regent Park,Harbourfront
# 14      M5B  Toronto                            Ryerson,Garden District
# 15      M5C  Toronto                                     St. James Town
# 16      M5E  Toronto                                        Berczy Park
# 17      M5G  Toronto                                 Central Bay Street
# 18      M5H  Toronto                             Adelaide,Richmond,King
# 19      M5J  Toronto    Harbourfront East,Toronto Islands,Union Station
# 20      M5K  Toronto            Design Exchange,Toronto Dominion Centre
# 21      M5L  Toronto                      Commerce Court,Victoria Hotel
# 22      M5N  Toronto                                           Roselawn
# 23      M5P  Toronto                 Forest Hill West,Forest Hill North
# 24      M5R  Toronto                  Yorkville,The Annex,North Midtown
# 25      M5S  Toronto                      University of Toronto,Harbord
# 26      M5T  Toronto            Chinatown,Kensington Market,Grange Park
# 27      M5V  Toronto  King and Spadina,Island airport,Bathurst Quay,...
# 28      M5W  Toronto                    Stn A PO Boxes 25 The Esplanade
# 29      M5X  Toronto              First Canadian Place,Underground city
# 30      M6G  Toronto                                           Christie
# 31      M6H  Toronto                        Dufferin,Dovercourt Village
# 32      M6J  Toronto                            Trinity,Little Portugal
# 33      M6K  Toronto         Exhibition Place,Parkdale Village,Brockton
# 34      M6P  Toronto                       The Junction South,High Park
# 35      M6R  Toronto                              Roncesvalles,Parkdale
# 36      M6S  Toronto                                  Runnymede,Swansea
# 37      M7Y  Toronto  Business Reply Mail Processing Centre 969 Eastern
#
#      Latitude  Longitude
# 0   43.676357 -79.293031
# 1   43.679557 -79.352188
# 2   43.668999 -79.315572
# 3   43.659526 -79.340923
# 4   43.728020 -79.388790
# 5   43.712751 -79.390197
# 6   43.715383 -79.405678
# 7   43.704324 -79.388790
# 8   43.689574 -79.383160
# 9   43.686412 -79.400049
# 10  43.679563 -79.377529
# 11  43.667967 -79.367675
# 12  43.665860 -79.383160
# 13  43.654260 -79.360636
# 14  43.657162 -79.378937
# 15  43.651494 -79.375418
# 16  43.644771 -79.373306
# 17  43.657952 -79.387383
# 18  43.650571 -79.384568
# 19  43.640816 -79.381752
# 20  43.647177 -79.381576
# 21  43.648198 -79.379817
# 22  43.711695 -79.416936
# 23  43.696948 -79.411307
# 24  43.672710 -79.405678
# 25  43.662696 -79.400049
# 26  43.653206 -79.400049
# 27  43.628947 -79.394420
# 28  43.646435 -79.374846
# 29  43.648429 -79.382280
# 30  43.669542 -79.422564
# 31  43.669005 -79.442259
# 32  43.647927 -79.419750
# 33  43.636847 -79.428191
# 34  43.661608 -79.464763
# 35  43.648960 -79.456325
# 36  43.651571 -79.484450
# 37  43.662744 -79.321558

# %% [markdown]
# # Step 6 : Setting up FourSquare API

# %%
CLIENT_ID = 'CCO0NCOVINXKNMLFOGJOPP2AUSXP44IJI5054EIYDOHPVHE0' # your Foursquare ID
CLIENT_SECRET = 'OUPMUQJEZ5VFSUFPDX3CBJXHNAPQAOWKPAAHK0NDFXCJNFXH' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
radius =50
LIMIT=100
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import json

# %% [markdown]
# # Step 7: Analyzing all Toronto neighbourhoods

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

toronto_venues = getNearbyVenues(names=toronto_data['Neighbourhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
#print(toronto_venues.shape)
#toronto_venues.head()
#toronto_venues.groupby('Neighborhood').count()
#print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head()
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped
# Out:
#                                         Neighbourhood  Adult Boutique  \
# 0                              Adelaide,Richmond,King        0.000000
# 1                                         Berczy Park        0.000000
# 2   Business Reply Mail Processing Centre 969 Eastern        0.000000
# 3                          Cabbagetown,St. James Town        0.000000
# 4                                  Central Bay Street        0.000000
# 5             Chinatown,Kensington Market,Grange Park        0.000000
# 6                                            Christie        0.000000
# 7                                Church and Wellesley        0.011628
# 8                       Commerce Court,Victoria Hotel        0.000000
# 9                                          Davisville        0.000000
# 10                                   Davisville North        0.000000
# 11            Design Exchange,Toronto Dominion Centre        0.000000
# 12                        Dufferin,Dovercourt Village        0.000000
# 13         Exhibition Place,Parkdale Village,Brockton        0.000000
# 14              First Canadian Place,Underground city        0.000000
# 15                 Forest Hill West,Forest Hill North        0.000000
# 16    Harbourfront East,Toronto Islands,Union Station        0.000000
# 17  King and Spadina,Island airport,Bathurst Quay,...        0.000000
# 18                                      Lawrence Park        0.000000
# 19                                 North Toronto West        0.000000
# 20                           Regent Park,Harbourfront        0.000000
# 21                              Roncesvalles,Parkdale        0.000000
# 22                                           Rosedale        0.000000
# 23                                           Roselawn        0.000000
# 24                                  Runnymede,Swansea        0.000000
# 25                            Ryerson,Garden District        0.000000
# 26                                     St. James Town        0.000000
# 27                    Stn A PO Boxes 25 The Esplanade        0.000000
# 28                                    Studio District        0.000000
# 29                         Summerhill East,Moore Park        0.000000
# 30  Summerhill West,Forest Hill SE,Deer Park,Rathn...        0.000000
# 31                                        The Beaches        0.000000
# 32                      The Beaches West,India Bazaar        0.000000
# 33                        The Danforth West,Riverdale        0.000000
# 34                       The Junction South,High Park        0.000000
# 35                            Trinity,Little Portugal        0.000000
# 36                      University of Toronto,Harbord        0.000000
# 37                  Yorkville,The Annex,North Midtown        0.000000
#
#     Afghan Restaurant   Airport  Airport Food Court  Airport Gate  \
# 0            0.000000  0.000000            0.000000      0.000000
# 1            0.000000  0.000000            0.000000      0.000000
# 2            0.000000  0.000000            0.000000      0.000000
# 3            0.000000  0.000000            0.000000      0.000000
# 4            0.000000  0.000000            0.000000      0.000000
# 5            0.000000  0.000000            0.000000      0.000000
# 6            0.000000  0.000000            0.000000      0.000000
# 7            0.011628  0.000000            0.000000      0.000000
# 8            0.000000  0.000000            0.000000      0.000000
# 9            0.000000  0.000000            0.000000      0.000000
# 10           0.000000  0.000000            0.000000      0.000000
# 11           0.000000  0.000000            0.000000      0.000000
# 12           0.000000  0.000000            0.000000      0.000000
# 13           0.000000  0.000000            0.000000      0.000000
# 14           0.000000  0.000000            0.000000      0.000000
# 15           0.000000  0.000000            0.000000      0.000000
# 16           0.000000  0.000000            0.000000      0.000000
# 17           0.000000  0.071429            0.071429      0.071429
# 18           0.000000  0.000000            0.000000      0.000000
# 19           0.000000  0.000000            0.000000      0.000000
# 20           0.000000  0.000000            0.000000      0.000000
# 21           0.000000  0.000000            0.000000      0.000000
# 22           0.000000  0.000000            0.000000      0.000000
# 23           0.000000  0.000000            0.000000      0.000000
# 24           0.000000  0.000000            0.000000      0.000000
# 25           0.000000  0.000000            0.000000      0.000000
# 26           0.000000  0.000000            0.000000      0.000000
# 27           0.000000  0.000000            0.000000      0.000000
# 28           0.000000  0.000000            0.000000      0.000000
# 29           0.000000  0.000000            0.000000      0.000000
# 30           0.000000  0.000000            0.000000      0.000000
# 31           0.000000  0.000000            0.000000      0.000000
# 32           0.000000  0.000000            0.000000      0.000000
# 33           0.000000  0.000000            0.000000      0.000000
# 34           0.000000  0.000000            0.000000      0.000000
# 35           0.000000  0.000000            0.000000      0.000000
# 36           0.000000  0.000000            0.000000      0.000000
# 37           0.000000  0.000000            0.000000      0.000000
#
#     Airport Lounge  Airport Service  Airport Terminal  American Restaurant  \
# 0         0.000000         0.000000          0.000000             0.040000
# 1         0.000000         0.000000          0.000000             0.000000
# 2         0.000000         0.000000          0.000000             0.000000
# 3         0.000000         0.000000          0.000000             0.020833
# 4         0.000000         0.000000          0.000000             0.012048
# 5         0.000000         0.000000          0.000000             0.000000
# 6         0.000000         0.000000          0.000000             0.000000
# 7         0.000000         0.000000          0.000000             0.011628
# 8         0.000000         0.000000          0.000000             0.040000
# 9         0.000000         0.000000          0.000000             0.000000
# 10        0.000000         0.000000          0.000000             0.000000
# 11        0.000000         0.000000          0.000000             0.040000
# 12        0.000000         0.000000          0.000000             0.000000
# 13        0.000000         0.000000          0.000000             0.000000
# 14        0.000000         0.000000          0.000000             0.040000
# 15        0.000000         0.000000          0.000000             0.000000
# 16        0.000000         0.000000          0.000000             0.000000
# 17        0.142857         0.142857          0.142857             0.000000
# 18        0.000000         0.000000          0.000000             0.000000
# 19        0.000000         0.000000          0.000000             0.000000
# 20        0.000000         0.000000          0.000000             0.000000
# 21        0.000000         0.000000          0.000000             0.000000
# 22        0.000000         0.000000          0.000000             0.000000
# 23        0.000000         0.000000          0.000000             0.000000
# 24        0.000000         0.000000          0.000000             0.000000
# 25        0.000000         0.000000          0.000000             0.010000
# 26        0.000000         0.000000          0.000000             0.020000
# 27        0.000000         0.000000          0.000000             0.010526
# 28        0.000000         0.000000          0.000000             0.050000
# 29        0.000000         0.000000          0.000000             0.000000
# 30        0.000000         0.000000          0.000000             0.071429
# 31        0.000000         0.000000          0.000000             0.000000
# 32        0.000000         0.000000          0.000000             0.000000
# 33        0.000000         0.000000          0.000000             0.023810
# 34        0.000000         0.000000          0.000000             0.000000
# 35        0.000000         0.000000          0.000000             0.015873
# 36        0.000000         0.000000          0.000000             0.000000
# 37        0.000000         0.000000          0.000000             0.041667
#
#        ...         Trail  Train Station  Vegetarian / Vegan Restaurant  \
# 0      ...       0.00000           0.00                       0.010000
# 1      ...       0.00000           0.00                       0.000000
# 2      ...       0.00000           0.00                       0.000000
# 3      ...       0.00000           0.00                       0.000000
# 4      ...       0.00000           0.00                       0.012048
# 5      ...       0.00000           0.00                       0.050000
# 6      ...       0.00000           0.00                       0.000000
# 7      ...       0.00000           0.00                       0.000000
# 8      ...       0.00000           0.00                       0.000000
# 9      ...       0.00000           0.00                       0.000000
# 10     ...       0.00000           0.00                       0.000000
# 11     ...       0.00000           0.01                       0.000000
# 12     ...       0.00000           0.00                       0.000000
# 13     ...       0.00000           0.00                       0.000000
# 14     ...       0.00000           0.01                       0.010000
# 15     ...       0.25000           0.00                       0.000000
# 16     ...       0.00000           0.01                       0.010000
# 17     ...       0.00000           0.00                       0.000000
# 18     ...       0.00000           0.00                       0.000000
# 19     ...       0.00000           0.00                       0.000000
# 20     ...       0.00000           0.00                       0.000000
# 21     ...       0.00000           0.00                       0.000000
# 22     ...       0.25000           0.00                       0.000000
# 23     ...       0.00000           0.00                       0.000000
# 24     ...       0.00000           0.00                       0.025000
# 25     ...       0.00000           0.00                       0.010000
# 26     ...       0.00000           0.00                       0.000000
# 27     ...       0.00000           0.00                       0.000000
# 28     ...       0.00000           0.00                       0.000000
# 29     ...       0.00000           0.00                       0.000000
# 30     ...       0.00000           0.00                       0.000000
# 31     ...       0.00000           0.00                       0.000000
# 32     ...       0.00000           0.00                       0.000000
# 33     ...       0.02381           0.00                       0.000000
# 34     ...       0.00000           0.00                       0.000000
# 35     ...       0.00000           0.00                       0.015873
# 36     ...       0.00000           0.00                       0.000000
# 37     ...       0.00000           0.00                       0.041667
#
#     Video Game Store  Vietnamese Restaurant  Wine Bar  Wine Shop  Wings Joint  \
# 0           0.000000               0.000000  0.010000       0.00     0.000000
# 1           0.000000               0.000000  0.000000       0.00     0.000000
# 2           0.000000               0.000000  0.000000       0.00     0.000000
# 3           0.000000               0.000000  0.000000       0.00     0.000000
# 4           0.000000               0.000000  0.012048       0.00     0.000000
# 5           0.000000               0.050000  0.010000       0.00     0.000000
# 6           0.000000               0.000000  0.000000       0.00     0.000000
# 7           0.011628               0.011628  0.000000       0.00     0.011628
# 8           0.000000               0.000000  0.010000       0.00     0.000000
# 9           0.000000               0.000000  0.000000       0.00     0.000000
# 10          0.000000               0.000000  0.000000       0.00     0.000000
# 11          0.000000               0.000000  0.010000       0.00     0.000000
# 12          0.000000               0.000000  0.000000       0.05     0.000000
# 13          0.000000               0.000000  0.000000       0.00     0.000000
# 14          0.000000               0.000000  0.010000       0.00     0.000000
# 15          0.000000               0.000000  0.000000       0.00     0.000000
# 16          0.000000               0.000000  0.010000       0.00     0.000000
# 17          0.000000               0.000000  0.000000       0.00     0.000000
# 18          0.000000               0.000000  0.000000       0.00     0.000000
# 19          0.000000               0.000000  0.000000       0.00     0.000000
# 20          0.000000               0.000000  0.000000       0.00     0.000000
# 21          0.000000               0.000000  0.000000       0.00     0.000000
# 22          0.000000               0.000000  0.000000       0.00     0.000000
# 23          0.000000               0.000000  0.000000       0.00     0.000000
# 24          0.000000               0.000000  0.000000       0.00     0.000000
# 25          0.010000               0.010000  0.010000       0.00     0.000000
# 26          0.000000               0.000000  0.000000       0.00     0.000000
# 27          0.000000               0.000000  0.000000       0.00     0.000000
# 28          0.000000               0.000000  0.000000       0.00     0.000000
# 29          0.000000               0.000000  0.000000       0.00     0.000000
# 30          0.000000               0.071429  0.000000       0.00     0.000000
# 31          0.000000               0.000000  0.000000       0.00     0.000000
# 32          0.000000               0.000000  0.000000       0.00     0.000000
# 33          0.000000               0.000000  0.000000       0.00     0.000000
# 34          0.000000               0.000000  0.000000       0.00     0.000000
# 35          0.000000               0.031746  0.015873       0.00     0.000000
# 36          0.027778               0.000000  0.000000       0.00     0.000000
# 37          0.000000               0.000000  0.000000       0.00     0.000000
#
#     Women's Store  Yoga Studio
# 0            0.01     0.000000
# 1            0.00     0.000000
# 2            0.00     0.055556
# 3            0.00     0.000000
# 4            0.00     0.012048
# 5            0.00     0.000000
# 6            0.00     0.000000
# 7            0.00     0.011628
# 8            0.00     0.000000
# 9            0.00     0.000000
# 10           0.00     0.000000
# 11           0.00     0.000000
# 12           0.00     0.000000
# 13           0.00     0.000000
# 14           0.00     0.000000
# 15           0.00     0.000000
# 16           0.00     0.000000
# 17           0.00     0.000000
# 18           0.00     0.000000
# 19           0.00     0.055556
# 20           0.00     0.000000
# 21           0.00     0.000000
# 22           0.00     0.000000
# 23           0.00     0.000000
# 24           0.00     0.000000
# 25           0.00     0.000000
# 26           0.01     0.010000
# 27           0.00     0.010526
# 28           0.00     0.025000
# 29           0.00     0.000000
# 30           0.00     0.000000
# 31           0.00     0.000000
# 32           0.00     0.000000
# 33           0.00     0.023810
# 34           0.00     0.000000
# 35           0.00     0.015873
# 36           0.00     0.000000
# 37           0.00     0.000000
#
# [38 rows x 243 columns]

# %% [markdown]
# # Step 8 : Creating a new dataframe to capture Neighbourhood venue frequency information

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]


num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                        Neighbourhood 1st Most Common Venue  \
# 0                             Adelaide,Richmond,King           Coffee Shop
# 1                                        Berczy Park           Coffee Shop
# 2  Business Reply Mail Processing Centre 969 Eastern    Light Rail Station
# 3                         Cabbagetown,St. James Town           Coffee Shop
# 4                                 Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café       Thai Restaurant            Steakhouse
# 1            Restaurant          Cocktail Bar                Bakery
# 2           Yoga Studio                Garden            Comic Shop
# 3            Restaurant                Bakery                Market
# 4                  Café    Italian Restaurant                   Bar
#
#   5th Most Common Venue 6th Most Common Venue      7th Most Common Venue  \
# 0   American Restaurant        Clothing Store                        Gym
# 1           Cheese Shop        Farmers Market                        Pub
# 2           Pizza Place                  Park           Recording Studio
# 3                  Café    Italian Restaurant                        Pub
# 4    Chinese Restaurant          Burger Joint  Middle Eastern Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                 Hotel                Bakery                    Bar
# 1    Seafood Restaurant              Beer Bar     Italian Restaurant
# 2            Restaurant               Butcher          Burrito Place
# 3              Pharmacy                  Park            Pizza Place
# 4     Indian Restaurant        Ice Cream Shop         Sandwich Place

# %% [markdown]
# # Step 9: Running clustering analysis on neighbourhoods based on types of venues

# %%
from sklearn.cluster import KMeans
# set number of clusters
kclusters = 7 # Iterative setting to find the best possible clusters
toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

toronto_merged.head() # check the last columns!
# Out:
#   Postcode  Borough                  Neighbourhood   Latitude  Longitude  \
# 0      M4E  Toronto                    The Beaches  43.676357 -79.293031
# 1      M4K  Toronto    The Danforth West,Riverdale  43.679557 -79.352188
# 2      M4L  Toronto  The Beaches West,India Bazaar  43.668999 -79.315572
# 3      M4M  Toronto                Studio District  43.659526 -79.340923
# 4      M4N  Toronto                  Lawrence Park  43.728020 -79.388790
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               6           Coffee Shop     Health Food Store
# 1               6      Greek Restaurant           Coffee Shop
# 2               0                   Gym               Brewery
# 3               6                  Café           Coffee Shop
# 4               3                  Park           Swim School
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0          Neighborhood                   Pub                  Park
# 1        Ice Cream Shop    Italian Restaurant             Bookstore
# 2      Sushi Restaurant            Steakhouse          Liquor Store
# 3    Italian Restaurant                Bakery   American Restaurant
# 4    Dim Sum Restaurant              Bus Line           Yoga Studio
#
#   6th Most Common Venue 7th Most Common Venue      8th Most Common Venue  \
# 0     Electronics Store      Doner Restaurant                 Donut Shop
# 1           Yoga Studio               Brewery                     Bakery
# 2     Fish & Chips Shop                  Park       Fast Food Restaurant
# 3           Fish Market             Bookstore  Middle Eastern Restaurant
# 4      Doner Restaurant   Filipino Restaurant       Fast Food Restaurant
#
#        9th Most Common Venue       10th Most Common Venue
# 0        Dumpling Restaurant  Eastern European Restaurant
# 1                  Juice Bar                 Liquor Store
# 2               Burger Joint                 Intersection
# 3  Latin American Restaurant                      Brewery
# 4             Farmers Market           Falafel Restaurant

# %% [markdown]
# # Step 9: Identification of different clusters
#    Iteratively looking at the 'Cluster Labels' from 0 to 6 , 2 dense clusters were identified for labels -0 and labels -6

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#     Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2   Toronto               0                   Gym               Brewery
# 5   Toronto               0     Food & Drink Shop                   Gym
# 7   Toronto               0           Pizza Place          Dessert Shop
# 12  Toronto               0   Japanese Restaurant           Coffee Shop
# 25  Toronto               0                  Café           Coffee Shop
# 26  Toronto               0                  Café                   Bar
# 27  Toronto               0        Airport Lounge       Airport Service
# 30  Toronto               0                  Café         Grocery Store
# 31  Toronto               0                Bakery              Pharmacy
# 32  Toronto               0                   Bar           Men's Store
# 34  Toronto               0    Mexican Restaurant                  Café
# 36  Toronto               0           Coffee Shop                  Café
# 37  Toronto               0    Light Rail Station           Yoga Studio
#
#             3rd Most Common Venue  4th Most Common Venue  \
# 2                Sushi Restaurant             Steakhouse
# 5                    Burger Joint         Clothing Store
# 7                  Sandwich Place       Sushi Restaurant
# 12               Sushi Restaurant                Gay Bar
# 25                         Bakery              Bookstore
# 26  Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 27               Airport Terminal          Boat or Ferry
# 30                           Park      Convenience Store
# 31                    Supermarket   Gym / Fitness Center
# 32                    Coffee Shop       Asian Restaurant
# 34           Fast Food Restaurant        Thai Restaurant
# 36                    Pizza Place       Sushi Restaurant
# 37                         Garden             Comic Shop
#
#    5th Most Common Venue  6th Most Common Venue      7th Most Common Venue  \
# 2           Liquor Store      Fish & Chips Shop                       Park
# 5                   Park         Sandwich Place                      Hotel
# 7            Coffee Shop     Italian Restaurant                       Café
# 12            Restaurant           Burger Joint                        Pub
# 25            Restaurant                Theater                        Bar
# 26                Bakery            Coffee Shop        Dumpling Restaurant
# 27              Boutique                Airport         Airport Food Court
# 30            Restaurant             Baby Store                  Nightclub
# 31           Pizza Place                   Pool                Music Venue
# 32           Pizza Place  Vietnamese Restaurant                 Restaurant
# 34   Fried Chicken Joint                 Bakery  Cajun / Creole Restaurant
# 36    Italian Restaurant               Pharmacy  South American Restaurant
# 37           Pizza Place                   Park           Recording Studio
#
#        8th Most Common Venue 9th Most Common Venue     10th Most Common Venue
# 2       Fast Food Restaurant          Burger Joint               Intersection
# 5             Breakfast Spot           Event Space                    Dog Run
# 7                        Gym    Seafood Restaurant                Flower Shop
# 12  Mediterranean Restaurant             Gastropub       Fast Food Restaurant
# 25       Japanese Restaurant             Nightclub               Noodle House
# 26        Chinese Restaurant    Mexican Restaurant               Dessert Shop
# 27              Airport Gate                 Plane            Harbor / Marina
# 30                     Diner    Italian Restaurant         Athletics & Sports
# 31            Discount Store                  Café  Middle Eastern Restaurant
# 32                    Bakery          Cocktail Bar                       Café
# 34    Furniture / Home Store    Italian Restaurant                Music Venue
# 36             Smoothie Shop             Bookstore                   Boutique
# 37                Restaurant               Butcher              Burrito Place

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 6, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#     Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0   Toronto               6           Coffee Shop     Health Food Store
# 1   Toronto               6      Greek Restaurant           Coffee Shop
# 3   Toronto               6                  Café           Coffee Shop
# 6   Toronto               6        Clothing Store   Sporting Goods Shop
# 9   Toronto               6                   Pub           Coffee Shop
# 11  Toronto               6           Coffee Shop            Restaurant
# 13  Toronto               6           Coffee Shop                Bakery
# 14  Toronto               6           Coffee Shop        Clothing Store
# 15  Toronto               6           Coffee Shop            Restaurant
# 16  Toronto               6           Coffee Shop            Restaurant
# 17  Toronto               6           Coffee Shop                  Café
# 18  Toronto               6           Coffee Shop                  Café
# 19  Toronto               6           Coffee Shop              Aquarium
# 20  Toronto               6           Coffee Shop                  Café
# 21  Toronto               6           Coffee Shop                  Café
# 24  Toronto               6        Sandwich Place                  Café
# 28  Toronto               6           Coffee Shop            Restaurant
# 29  Toronto               6           Coffee Shop                  Café
# 33  Toronto               6        Breakfast Spot           Coffee Shop
# 35  Toronto               6             Gift Shop        Breakfast Spot
#
#    3rd Most Common Venue      4th Most Common Venue   5th Most Common Venue  \
# 0           Neighborhood                        Pub                    Park
# 1         Ice Cream Shop         Italian Restaurant               Bookstore
# 3     Italian Restaurant                     Bakery     American Restaurant
# 6            Coffee Shop                Yoga Studio                    Park
# 9      Convenience Store         Light Rail Station        Sushi Restaurant
# 11                Bakery                     Market                    Café
# 13                  Café                       Park                     Pub
# 14                  Café  Middle Eastern Restaurant          Cosmetics Shop
# 15                  Café                      Hotel          Clothing Store
# 16          Cocktail Bar                     Bakery             Cheese Shop
# 17    Italian Restaurant                        Bar      Chinese Restaurant
# 18       Thai Restaurant                 Steakhouse     American Restaurant
# 19                 Hotel                       Café             Pizza Place
# 20                 Hotel                 Restaurant     American Restaurant
# 21                 Hotel                 Restaurant     American Restaurant
# 24           Coffee Shop                Pizza Place          Cosmetics Shop
# 28                  Café                      Hotel                     Pub
# 29                 Hotel                 Restaurant     American Restaurant
# 33                  Café                        Bar  Furniture / Home Store
# 35         Movie Theater                       Bank                     Bar
#
#    6th Most Common Venue      7th Most Common Venue  \
# 0      Electronics Store           Doner Restaurant
# 1            Yoga Studio                    Brewery
# 3            Fish Market                  Bookstore
# 6     Chinese Restaurant        Rental Car Location
# 9            Supermarket                 Sports Bar
# 11    Italian Restaurant                        Pub
# 13               Theater             Breakfast Spot
# 14   Japanese Restaurant         Italian Restaurant
# 15          Cocktail Bar             Cosmetics Shop
# 16        Farmers Market                        Pub
# 17          Burger Joint  Middle Eastern Restaurant
# 18        Clothing Store                        Gym
# 19    Italian Restaurant             Scenic Lookout
# 20    Italian Restaurant              Deli / Bodega
# 21         Deli / Bodega         Seafood Restaurant
# 24   American Restaurant                  BBQ Joint
# 28              Beer Bar               Cocktail Bar
# 29                   Gym                     Bakery
# 33             Nightclub               Climbing Gym
# 35             Bookstore                    Dog Run
#
#         8th Most Common Venue      9th Most Common Venue  \
# 0                  Donut Shop        Dumpling Restaurant
# 1                      Bakery                  Juice Bar
# 3   Middle Eastern Restaurant  Latin American Restaurant
# 6                Dessert Shop         Salon / Barbershop
# 9         Fried Chicken Joint        American Restaurant
# 11                   Pharmacy                       Park
# 13         Mexican Restaurant                 Restaurant
# 14                 Restaurant                Pizza Place
# 15                     Bakery                       Park
# 16         Seafood Restaurant                   Beer Bar
# 17          Indian Restaurant             Ice Cream Shop
# 18                      Hotel                     Bakery
# 19                     Bakery                 Restaurant
# 20                  Gastropub         Seafood Restaurant
# 21         Italian Restaurant                 Steakhouse
# 24                        Pub          Indian Restaurant
# 28         Italian Restaurant         Seafood Restaurant
# 29                        Bar                  Gastropub
# 33         Italian Restaurant              Burrito Place
# 35                 Restaurant         Italian Restaurant
#
#          10th Most Common Venue
# 0   Eastern European Restaurant
# 1                  Liquor Store
# 3                       Brewery
# 6                Sandwich Place
# 9         Vietnamese Restaurant
# 11                  Pizza Place
# 13         Gym / Fitness Center
# 14                        Plaza
# 15           Italian Restaurant
# 16           Italian Restaurant
# 17               Sandwich Place
# 18                          Bar
# 19                      Brewery
# 20                 Burger Joint
# 21                       Bakery
# 24                 Liquor Store
# 28               Cosmetics Shop
# 29                   Steakhouse
# 33                      Stadium
# 35                 Burger Joint

# %% [markdown]
# # Step 10 : Two Key clusters were noticed -  Label (0) - having cafes and Label (6)- having coffee shops as the highest no of venues in the locality of Toronto

# %%
clusters= pd.DataFrame(toronto_merged.groupby('Cluster Labels', as_index=False).agg(lambda x: set(x)))
clusters
clusters['Neighbourhood']
# Out:
# 0    {The Beaches West,India Bazaar, King and Spadi...
# 1                                           {Roselawn}
# 2                                           {Rosedale}
# 3                                      {Lawrence Park}
# 4                         {Summerhill East,Moore Park}
# 5                 {Forest Hill West,Forest Hill North}
# 6    {Yorkville,The Annex,North Midtown, Design Exc...
# Name: Neighbourhood, dtype: object
